# %%
import pandas as pd
import re

# %%
address = 'result.csv'
data_1 = pd.read_csv(address)
data_1
# Out:
#                     JobTitle                             Company  \
# 0                        new             Apogee Digitech Pvt Ltd
# 1          PHP Web Developer                          Beak Media
# 2              Web Developer  Makebot Robotic Solutions Pvt. Ltd
# 3                        new                    GIT Technologies
# 4              Web Developer     PTS Systems & Solutions Pvt Ltd
# 5                        new                            ARCITECH
# 6              WEB DEVELOPER                 Maxval Technologies
# 7    Front-End Web Developer                                 TIC
# 8              Web Developer                 Nora Tecnoanalytics
# 9             HTML Developer                G-ORDINATEUR PVT LTD
# 10             Web Developer                              GAMSYS
# 11  Web Designer & Developer    GIT Technologies Private Limited
# 12             Web Developer                 The Marketing Nerdz
# ...

# %%
x = data_1['JobTitle']
type(x)
# Out:
# pandas.core.series.Series

# %%
str_1 = ' ' + x
x_1 = []
for i in str_1:
    x = re.sub('new','Web developer',i)
#     x = x_1
    print(x)
# Out:
#  Web developer
#  PHP Web Developer
#  Web Developer
#  Web developer
#  Web Developer
#  Web developer
#  WEB DEVELOPER
#  Front-End Web Developer
#  Web Developer
#  HTML Developer
#  Web Developer
#  Web Designer & Developer
#  Web Developer
#  Web developer
#  Web developer

# %%
Y = data_1['Summary']
Y
# Out:
# 0     \nRegular exposure to business stakeholders an...
# 1     \nSalary: *Rs 35000 - Rs 50000 per month (fina...
# 2     \nWorking closely with web designers and progr...
# 3     \nSkills At least 1 - 2 years of experience us...
# 4     \nWriting well designed, testable, efficient c...
# 5     \nAssist in troubleshooting issues on web-base...
# 6     \nProficient understanding of web markup, incl...
# 7     \nProficient understanding of web markup, incl...
# 8     \nJob Type: Developers with knowledge of , HTM...
# 9     \nExperience building large consumer web appli...
# 10    \nDeveloping mobile Friendly and responsive we...
# 11    \nWeb designing: 2 years (Required).\nRegular ...
# 12    \nYou must have mastery in creating a website ...
# 13    \nWrite well designed, testable, efficient cod...
# 14    \nAny graduate, Should have good verbal and wr...
# Name: Summary, dtype: object

# %%
arr_str = []
for i in Y:
    a = re.search('\n',i)
    i = re.split
    print(a)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(0, 1), match='\n'>
